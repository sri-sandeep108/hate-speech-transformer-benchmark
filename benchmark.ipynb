# %%
# !python -m spacy benchmark accuracy output/static_vector/model-best/ docbins/test.spacy --output results/static_vector/ -g 0
# Out:
# ℹ Using GPU: 0
#
# ================================== Results ==================================
#
# TOK                 100.00
# TEXTCAT (macro F)   74.53
# SPEED               135161
#
#
# =========================== Textcat F (per label) ===========================
#
#                   P       R       F
# Hateful       56.21   61.07   58.54
# Not-Hateful   91.38   89.66   90.51
#
#
# ======================== Textcat ROC AUC (per label) ========================
#
#               ROC AUC
# Hateful          0.85
# Not-Hateful      0.85
#
# ✔ Saved results to results/static_vector

# %%
# !python -m spacy benchmark accuracy output/bert/model-best/ docbins/test.spacy --output results/bert/ -g 0
# Out:
# ℹ Using GPU: 0
#
# ================================== Results ==================================
#
# TOK                 100.00
# TEXTCAT (macro F)   79.93
# SPEED               35184
#
#
# =========================== Textcat F (per label) ===========================
#
#                   P       R       F
# Hateful       66.75   67.37   67.06
# Not-Hateful   92.89   92.71   92.80
#
#
# ======================== Textcat ROC AUC (per label) ========================
#
#               ROC AUC
# Hateful          0.92
# Not-Hateful      0.92
#
# ✔ Saved results to results/bert

# %%
# !python -m spacy benchmark accuracy output/roberta/model-best/ docbins/test.spacy --output results/roberta/ -g 0
# Out:
# ℹ Using GPU: 0
# Token indices sequence length is longer than the specified maximum sequence length for this model (2459 > 500). Running this sequence through the model will result in indexing errors
#
# ================================== Results ==================================
#
# TOK                 100.00
# TEXTCAT (macro F)   76.03
# SPEED               33673
#
#
# =========================== Textcat F (per label) ===========================
#
#                   P       R       F
# Hateful       58.08   64.40   61.08
# Not-Hateful   92.08   89.90   90.98
#
#
# ======================== Textcat ROC AUC (per label) ========================
#
#               ROC AUC
# Hateful          0.88
# Not-Hateful      0.88
#
# ✔ Saved results to results/roberta

# %%
# !python -m spacy benchmark accuracy output/distilbert/model-best/ docbins/test.spacy --output results/distilbert/ -g 0
# Out:
# ℹ Using GPU: 0
#
# ================================== Results ==================================
#
# TOK                 100.00
# TEXTCAT (macro F)   81.09
# SPEED               41238
#
#
# =========================== Textcat F (per label) ===========================
#
#                   P       R       F
# Hateful       66.87   71.65   69.18
# Not-Hateful   93.74   92.29   93.01
#
#
# ======================== Textcat ROC AUC (per label) ========================
#
#               ROC AUC
# Hateful          0.93
# Not-Hateful      0.93
#
# ✔ Saved results to results/distilbert

# %%
# !python -m spacy benchmark accuracy output/electra/model-best/ docbins/test.spacy --output results/electra/ -g 0
# Out:
# ℹ Using GPU: 0
#
# ================================== Results ==================================
#
# TOK                 100.00
# TEXTCAT (macro F)   80.60
# SPEED               34802
#
#
# =========================== Textcat F (per label) ===========================
#
#                   P       R       F
# Hateful       67.69   68.67   68.18
# Not-Hateful   93.17   92.88   93.02
#
#
# ======================== Textcat ROC AUC (per label) ========================
#
#               ROC AUC
# Hateful          0.92
# Not-Hateful      0.92
#
# ✔ Saved results to results/electra
